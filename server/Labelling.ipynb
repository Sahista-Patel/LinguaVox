# %% [markdown]
# https://github.com/tzutalin/labelImg
#
# https://www.youtube.com/watch?v=yqkISICHH-U

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in d:\anaconda3\lib\site-packages (5.15.4)
# Requirement already satisfied: lxml in d:\anaconda3\lib\site-packages (4.6.1)
# Collecting lxml
#   Using cached lxml-4.6.3-cp38-cp38-win_amd64.whl (3.5 MB)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in d:\anaconda3\lib\site-packages (from pyqt5) (12.8.1)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in d:\anaconda3\lib\site-packages (from pyqt5) (5.15.2)
# Installing collected packages: lxml
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.6.1
#     Uninstalling lxml-4.6.1:
#       Successfully uninstalled lxml-4.6.1
# Successfully installed lxml-4.6.3

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.12.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asgiref                            3.3.1
# asn1crypto                         1.4.0
# astor                              0.8.1
# astroid                            2.4.2
# astropy                            4.0.2
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.1
# bkcharts                           0.2
# bleach                             3.2.1
# bokeh                              2.2.3
# boto                               2.49.0
# boto3                              1.17.44
# botocore                           1.20.44
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         4.2.1
# certifi                            2020.6.20
# cffi                               1.14.3
# chardet                            3.0.4
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.7
# conda                              4.9.2
# conda-build                        3.20.5
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# configparser                       5.0.1
# confuse                            1.4.0
# contextlib2                        0.6.0.post1
# crayons                            0.4.0
# cryptography                       3.1.1
# cssselect                          1.1.0
# cycler                             0.10.0
# Cython                             0.29.21
# cytoolz                            0.11.0
# dask                               2.30.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# diff-match-patch                   20200713
# distributed                        2.30.1
# Django                             3.1.7
# dnspython                          2.1.0
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastapi                            0.63.0
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# Flask                              1.1.2
# flatbuffers                        1.12
# fsspec                             0.8.3
# future                             0.18.2
# gast                               0.3.3
# gevent                             20.9.0
# glob2                              0.7
# google-auth                        1.28.0
# google-auth-oauthlib               0.4.3
# google-pasta                       0.2.0
# greenlet                           0.4.17
# grpcio                             1.32.0
# h11                                0.12.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# htmlmin                            0.1.12
# idna                               2.10
# image                              1.5.33
# ImageHash                          4.2.0
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 2.0.0
# importlib-resources                5.1.2
# iniconfig                          1.1.1
# instaloader                        4.6.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.19.0
# ipython_genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              5.6.4
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.1
# Jinja2                             2.11.2
# jmespath                           0.10.0
# joblib                             0.17.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.7
# jupyter-console                    6.2.0
# jupyter-core                       4.6.3
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# Keras                              2.4.3
# Keras-Preprocessing                1.1.2
# keyring                            21.4.0
# kiwisolver                         1.3.0
# knnimpute                          0.1.0
# lazy-object-proxy                  1.4.3
# lib                                3.0.0
# libarchive-c                       2.9
# llvmlite                           0.34.0
# locket                             0.2.0
# lxml                               4.6.3
# Markdown                           3.3.4
# MarkupSafe                         1.1.1
# matplotlib                         3.3.2
# mccabe                             0.6.1
# menuinst                           1.4.16
# missingno                          0.4.2
# mistune                            0.8.4
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mlxtend                            0.18.0
# mock                               4.0.2
# more-itertools                     8.6.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.0.8
# nest-asyncio                       1.4.2
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.1.4
# numba                              0.51.2
# numexpr                            2.7.1
# numpy                              1.19.2
# numpydoc                           1.1.0
# oauthlib                           3.1.0
# olefile                            0.46
# opencv-python                      4.5.1.48
# openpyxl                           3.0.5
# opt-einsum                         3.3.0
# osqp                               0.6.2.post0
# packaging                          20.4
# pandas                             1.1.3
# pandas-profiling                   2.11.0
# pandasgui                          0.2.10.1
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parsel                             1.6.0
# parso                              0.7.0
# partd                              1.1.0
# path                               15.0.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# phik                               0.11.2
# pickleshare                        0.7.5
# Pillow                             8.0.1
# pip                                21.2.4
# pkginfo                            1.6.1
# plotly                             4.14.3
# plotly-express                     0.4.1
# pluggy                             0.13.1
# ply                                3.11
# progressbar                        2.5
# prometheus-client                  0.8.0
# prompt-toolkit                     3.0.8
# protobuf                           3.15.6
# psutil                             5.7.2
# py                                 1.9.0
# pyarrow                            3.0.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydantic                           1.7.3
# pydocstyle                         5.1.1
# pyflakes                           2.2.0
# Pygments                           2.7.2
# pylint                             2.6.0
# pymongo                            3.11.2
# PyNaCl                             1.4.0
# pynput                             1.7.3
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# PyQt5                              5.15.4
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.8.1
# PyQtWebEngine                      5.15.4
# PyQtWebEngine-Qt5                  5.15.2
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             0.0.0
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.35.1
# pytz                               2020.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              19.0.2
# QDarkStyle                         2.8.1
# qdldl                              0.1.5.post0
# QtAwesome                          1.0.1
# qtconsole                          4.7.7
# QtPy                               1.9.0
# regex                              2020.10.15
# requests                           2.24.0
# requests-oauthlib                  1.3.0
# retrying                           1.3.3
# rope                               0.18.0
# rsa                                4.7.2
# Rtree                              0.9.4
# ruamel_yaml                        0.15.87
# s3transfer                         0.3.6
# sacremoses                         0.0.43
# scikit-image                       0.17.2
# scikit-learn                       0.24.1
# scikit-multilearn                  0.2.0
# scipy                              1.5.2
# seaborn                            0.11.0
# selectorlib                        0.16.0
# selenium                           3.141.0
# Send2Trash                         1.5.0
# sentencepiece                      0.1.95
# seqeval                            1.2.2
# setuptools                         50.3.1.post20201107
# simplegeneric                      0.8.1
# simpletransformers                 0.32.3
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.15.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.2.2
# soupsieve                          2.0.1
# Sphinx                             3.2.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.1.5
# spyder-kernels                     1.9.4
# SQLAlchemy                         1.3.20
# sqlparse                           0.4.1
# starlette                          0.13.6
# statsmodels                        0.12.0
# sweetviz                           2.0.9
# sympy                              1.6.2
# tables                             3.6.1
# tangled-up-in-unicode              0.0.7
# tblib                              1.7.0
# tensorboard                        2.4.1
# tensorboard-plugin-wit             1.8.0
# tensorboardX                       2.1
# tensorflow                         2.4.1
# tensorflow-estimator               2.4.0
# termcolor                          1.1.0
# terminado                          0.9.1
# testpath                           0.4.4
# textblob                           0.15.3
# threadpoolctl                      2.1.0
# tifffile                           2020.10.1
# tokenizers                         0.7.0
# toml                               0.10.1
# toolz                              0.11.1
# torch                              1.8.1
# tornado                            6.0.4
# tqdm                               4.50.2
# traitlets                          5.0.5
# transformers                       2.11.0
# tweepy                             3.10.0
# typing-extensions                  3.7.4.3
# ujson                              4.0.1
# unicodecsv                         0.14.1
# urllib3                            1.25.11
# uvicorn                            0.13.3
# vaderSentiment                     3.3.2
# vincent                            0.4.4
# visions                            0.6.0
# w3lib                              1.22.0
# watchdog                           0.10.3
# wcwidth                            0.2.5
# webdriver-manager                  3.3.0
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.1
# wrapt                              1.12.1
# xgboost                            1.3.3
# xlrd                               1.2.0
# XlsxWriter                         1.3.7
# xlwings                            0.20.8
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.1.2

# %%
import os
LABELING_PATH = os.path.join('Tensorflow','labelimg')

# %%
if not os.path.exists(LABELING_PATH):
    # !mkdir {LABELING_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELING_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
# pyrcc5 -o libs/resources.py resources.qrc
